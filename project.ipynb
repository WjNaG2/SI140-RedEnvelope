# %% [markdown]
# 《微信红包“手气最佳接龙”的机制分析与最优参与策略研究》

# %% [markdown]
# 一、摘要

# %% [markdown]
# 二、关键词

# %% [markdown]
# 三、引言

# %% [markdown]
# 四、研究过程
#
# （一）微信红包机制分析
#
# 1、数据统计
#
# 数据+图标
#
# 2、样本数据分析
#
# 3、机制猜测
#
#     1、均匀分布
#
#     2、条件均匀分布
#
#     3、条件均匀分布改
#
# 4、模型建立
#
#
# 5、模型验证
#
#     1、p值检验
#
#     2、卡方检验
#
#     3、大模型检验
#
# 6、微信红包机制结论
#
# （二）基于猜测模型的手气最佳分析
#
# 1、数据统计
#
# 2、样本数据分析
#
# 3、模型建立
#
# 4、模型验证
#
#
# （三）基于现有结论对于“手气最佳”接龙规则的最优方案设计
#
# （先随便设计一个方案，计算他的期望，方差等数据

# %%
五、结论
